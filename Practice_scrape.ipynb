# %% [markdown]
# <a href="https://colab.research.google.com/github/hemant7301/pppp/blob/main/Practice_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# !pip install requests
import scrapy
from scrapy.crawler import CrawlerProcess
import requests
import pandas as pd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.9 MB/s eta 0:00:00
# ...

# %%
class Spidey1(scrapy.Spider):
  name: str = "spidey1"

  def start_requests(self):
    urls = ['https://books.toscrape.com/index.html']
    for url in urls:
      yield scrapy.Request(url = url, callback= self.parse)
class Spidey1(scrapy.Spider):
  name: str = "spidey1"

  def start_requests(self):
    urls = ['https://books.toscrape.com/index.html']
    for url in urls:
      yield scrapy.Request(url = url, callback= self.parse)

  def parse(self, response):
    book_names = response.xpath('//article[@class = "product_pod"]/h3/a/text()').extract()
    prices = response.xpath('//p[@class = "price_color"]/text()').extract()
    file_path = 'book_names.txt'
    with open(file_path, 'w') as file:
      for book_names,price in zip(book_names,prices):
        file.write(f"{book_names}, {price}\n")

# %% [markdown]
# # New Section

# %%
russ = CrawlerProcess()
russ.crawl(Spidey1)
russ.start()
# Out:
# INFO:scrapy.utils.log:Scrapy 2.12.0 started (bot: scrapybot)
# 2025-02-27 08:13:13 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# INFO:scrapy.utils.log:Versions: lxml 5.3.1.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# 2025-02-27 08:13:13 [scrapy.utils.log] INFO: Versions: lxml 5.3.1.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.3, Platform Linux-6.1.85+-x86_64-with-glibc2.35
# INFO:scrapy.addons:Enabled addons:
# []
# 2025-02-27 08:13:13 [scrapy.addons] INFO: Enabled addons:
# []
# DEBUG:scrapy.utils.log:Using reactor: twisted.internet.epollreactor.EPollReactor
# ...

# %%
with open('book_names.txt', 'r') as file:
  file_content = file.read()
  print(file_content)
# Out:
# A Light in the ..., £51.77
# Tipping the Velvet, £53.74
# Soumission, £50.10
# Sharp Objects, £47.82
# Sapiens: A Brief History ..., £54.23
# The Requiem Red, £22.65
# The Dirty Little Secrets ..., £33.34
# The Coming Woman: A ..., £17.93
# The Boys in the ..., £22.60
# The Black Maria, £52.15
# Starving Hearts (Triangular Trade ..., £13.99
# Shakespeare's Sonnets, £20.66
# Set Me Free, £17.46
# Scott Pilgrim's Precious Little ..., £52.29
# Rip it Up and ..., £35.02
# Our Band Could Be ..., £57.25
# Olio, £23.88
# Mesaerion: The Best Science ..., £37.59
# Libertarianism for Beginners, £51.33
# It's Only the Himalayas, £45.17

# %%
# Assuming 'book_names.txt' exists and has the data in the format "book_name, price"
df = pd.read_csv('book_names.txt', header=None, names=['Book Name', 'Price'])
df
# Out:
#                                 Book Name    Price
# 0                      A Light in the ...   £51.77
# 1                      Tipping the Velvet   £53.74
# 2                              Soumission   £50.10
# 3                           Sharp Objects   £47.82
# 4            Sapiens: A Brief History ...   £54.23
# 5                         The Requiem Red   £22.65
# 6            The Dirty Little Secrets ...   £33.34
# 7                 The Coming Woman: A ...   £17.93
# 8                     The Boys in the ...   £22.60
# 9                         The Black Maria   £52.15
# 10  Starving Hearts (Triangular Trade ...   £13.99
# 11                  Shakespeare's Sonnets   £20.66
# 12                            Set Me Free   £17.46
# 13    Scott Pilgrim's Precious Little ...   £52.29
# 14                      Rip it Up and ...   £35.02
# 15                  Our Band Could Be ...   £57.25
# 16                                   Olio   £23.88
# ...
